# %%
# !pip install py7zr wget pandas > /dev/null

# %%
import os
import wget
import zipfile
import requests
import pandas as pd

# %%
SOURCE_URL = "https://portal.inmet.gov.br/uploads/dadoshistoricos/2025.zip"
INPUT_DIR = "./input"
EXTRACT_DIR = "./input/inmet_2025"

# %%
def download_zip_inmet(url: str, output_dir: str) -> str:
    os.makedirs(output_dir, exist_ok=True)

    filename = url.split("/")[-1]
    output_path = os.path.join(output_dir, filename)

    if os.path.exists(output_path):
        print("⚠️ Arquivo já existe, pulando download")
        return output_path

    print(f"📥 Downloading {filename}...")

    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/120.0 Safari/537.36"
    }

    with requests.get(url, headers=headers, stream=True, timeout=60) as r:
        r.raise_for_status()
        with open(output_path, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

    print("✅ Download concluído")
    return output_path

# %%
def extract_zip(zip_path: str, extract_dir: str):
    os.makedirs(extract_dir, exist_ok=True)

    print("📦 Extraindo arquivos...")
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(extract_dir)

    print("✅ Extração concluída")

# %%
zip_path = download_zip_inmet(SOURCE_URL, INPUT_DIR)
extract_zip(zip_path, EXTRACT_DIR)
# Out:
# 📥 Downloading 2025.zip...
# ✅ Download concluído
# 📦 Extraindo arquivos...
# ✅ Extração concluída

# %%
def listar_csvs(base_dir: str):
    arquivos = []
    for root, _, files in os.walk(base_dir):
        for f in files:
            if f.lower().endswith(".csv"):
                arquivos.append(os.path.join(root, f))
    return arquivos

# %%
def concat_csvs_to_dfs(csvs_list: list):

  dfs = []
  for arq in csvs_list:
      df = pd.read_csv(
          arq,
          sep=';',
          encoding='latin1',
          skiprows=8,          # INMET: ignora metadados iniciais
          decimal=',',
          na_values=['', ' ']
      )

      # adiciona origem
      df['arquivo_origem'] = arq.split('/')[-1]
      dfs.append(df)

  return pd.concat(dfs, ignore_index=True)

# %%
csvs_list = listar_csvs(EXTRACT_DIR)
df_imnet = concat_csvs_to_dfs(csvs_list)

# %%
df_imnet.head()
# Out:
#          Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2025/01/01  0000 UTC                               1.0
# 1  2025/01/01  0100 UTC                               0.0
# 2  2025/01/01  0200 UTC                               0.0
# 3  2025/01/01  0300 UTC                               8.2
# 4  2025/01/01  0400 UTC                               0.6
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                             1004.7
# 1                                             1005.1
# 2                                             1005.5
# 3                                             1006.1
# 4                                             1004.8
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           1004.7
# 1                                           1005.1
# 2                                           1005.5
# 3                                           1006.3
# 4                                           1006.2
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                            1003.7                      0.1
# 1                                            1004.7                      0.0
# 2                                            1004.8                      0.0
# 3                                            1005.5                      1.1
# 4                                            1004.8                      0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          24.2
# 1                                          24.8
# 2                                          24.8
# 3                                          23.2
# 4                                          23.2
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  22.4
# 1                                  22.8
# 2                                  23.0
# 3                                  22.3
# 4                                  22.3
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                        25.2  ...
# 1                                        24.8  ...
# 2                                        25.0  ...
# 3                                        24.9  ...
# 4                                        23.2  ...
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              23.1
# 1                                              23.0
# 2                                              23.2
# 3                                              23.6
# 4                                              22.3
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              22.1
# 1                                              22.5
# 2                                              22.7
# 3                                              21.9
# 4                                              21.9
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      90.0
# 1                                      91.0
# 2                                      90.0
# 3                                      95.0
# 4                                      95.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      85.0
# 1                                      89.0
# 2                                      89.0
# 3                                      90.0
# 4                                      94.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 90.0                                 121.0
# 1                                 89.0                                  47.0
# 2                                 90.0                                 119.0
# 3                                 95.0                                 185.0
# 4                                 95.0                                 318.0
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19  \
# 0                         5.3                              2.1          NaN
# 1                         3.9                              1.9          NaN
# 2                         3.3                              0.9          NaN
# 3                        12.1                              1.2          NaN
# 4                         3.7                              1.3          NaN
#
#                                       arquivo_origem
# 0  INMET_NE_MA_A255_ZE DOCA_01-01-2025_A_30-11-20...
# 1  INMET_NE_MA_A255_ZE DOCA_01-01-2025_A_30-11-20...
# 2  INMET_NE_MA_A255_ZE DOCA_01-01-2025_A_30-11-20...
# 3  INMET_NE_MA_A255_ZE DOCA_01-01-2025_A_30-11-20...
# 4  INMET_NE_MA_A255_ZE DOCA_01-01-2025_A_30-11-20...
#
# [5 rows x 21 columns]
