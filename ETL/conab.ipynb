# %%
# !pip install pandas > /dev/null

# %%
import pandas as pd

# %%
SOURCE = 'https://portaldeinformacoes.conab.gov.br/downloads/arquivos/PrecosMensalUF.txt'

# %%
df = pd.read_csv(
          SOURCE,
          sep=';',
          encoding='latin1',
          decimal=',',
          na_values=['', ' ']
      )

# %%
df.head()
# Out:
#                      produto   classificao_produto  id_produto          uf  \
# 0  ABACAXI                    PÉROLA                      6320  AC
# 1  ABACAXI                    PÉROLA                      6320  AL
# 2  ABACAXI                    PÉROLA                      6320  AM
# 3  ABACAXI                    PÉROLA                      6320  AP
# 4  ABACAXI                    PÉROLA                      6320  CE
#
#             regiao   ano  mes  \
# 0  NORTE            2024   12
# 1  NORDESTE         2024   12
# 2  NORTE            2024   12
# 3  NORTE            2024   12
# 4  NORDESTE         2024   12
#
#                            dsc_nivel_comercializacao  valor_produto_kg
# 0  PREÇO RECEBIDO P/ PRODUTOR                    ...              2.67
# 1  PREÇO RECEBIDO P/ PRODUTOR                    ...              3.33
# 2  PREÇO RECEBIDO P/ PRODUTOR                    ...              6.95
# 3  PREÇO RECEBIDO P/ PRODUTOR                    ...              4.30
# ...
